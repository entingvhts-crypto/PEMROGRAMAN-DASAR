# %% [markdown]
# <a href="https://colab.research.google.com/github/entingvhts-crypto/PEMROGRAMAN-DASAR/blob/main/Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "enting vincencia"
nim = 4232501038
jurusan = "elektro[RPE]"
semester = 3
matakuliah = 'Pemrograman Dasar'
hobi = "membaca, bernyanyi, dengerin musik, mencari kesibukan"
umur = 20
alamat = "Perum gmp blok b no 50"
status_lulus = False

print (nama)
print (nim)
print (jurusan)
print (semester)
print (matakuliah)
print (hobi)
print (umur)
print (alamat)
print (status_lulus)
# Out:
# enting vincencia
# 4232501038
# elektro[RPE]
# 3
# Pemrograman Dasar
# membaca, bernyanyi, dengerin musik, mencari kesibukan
# 20
# Perum gmp blok b no 50
# False

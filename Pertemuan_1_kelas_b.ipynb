# %% [markdown]
# <a href="https://colab.research.google.com/github/entingvhts-crypto/PEMROGRAMAN-DASAR/blob/main/Pertemuan_1_kelas_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "enting"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemrograman Dasar'
hobi = "makan"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (hobi)
print (status_lulus)
# Out:
# enting
# 20
# RPE
# 3
# Pemrograman Dasar
# makan
# False
